# %% [markdown]
# We beginnen met het importeren van de nodige modules: pandas, matplotlib en numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline    
## pd.options.display.mpl_style = 'default'

# %% [markdown]
# ##### Inlezen van de data set
#
# Voor het inlezen van een Series gebruiken we de functie pd.read_csv. (Zie: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)
# De eerste rij (rangnummer 0) van het bestand bevat de header, met de namen van de kolommen.
#
# je kunt het bestand bekijken met
# !cat JongerenSocialeNetwerken.csv
#
# voor het inlezen gebruik je:
# sociaal_netwerk = pd.read_csv("JSN1.csv", sep=";")
# daarna kun je het resultaat bekijken met:
#
# sociaal_netwerk of
# print(sociaal_netwerk)

# %%
sc = pd.read_excel("JSN.xlsx")
sc.head(7)
# Out:
#        id      Staat      Regio Woonomgeving Geslacht  Leeftijd  \
# 0  id0001    Florida      South        Urban        M        15
# 1  id0002       Ohio    Midwest     Suburban        V        16
# 2  id0003    Florida      South     Suburban        V        14
# 3  id0004   New York  Northeast        Urban        M        14
# 4  id0005  Louisiana      South     Suburban        V        16
# 5  id0006    Florida      South     Suburban        V        17
# 6  id0007       Ohio    Midwest        Urban        V        13
#
#   GebruiktInternet? InternetMobiel?                   AlgemeenVertrouwen  \
# 0                ja              ja  De meeste mensen zijn te vertrouwen
# 1                ja              ja  Je kan niet voorzichtig genoeg zijn
# 2                ja              ja  Je kan niet voorzichtig genoeg zijn
# 3                ja              ja  Je kan niet voorzichtig genoeg zijn
# 4                ja              ja            (geweigerd te antwoorden)
# ...

# %% [markdown]
# ### Nu gaan we een draaitabel maken
#
# In python is de instructie voor het maken van een draaitabel als volgt pd.pivot_table(dataset, index=["rij-variabele"], columns=["kolom-variabele"], values=["id"], aggfunc=len)
#
# Voor de rij-variabele kiezen we Leeftijd
# Voor de kolomvariabele kiezen we Regio
#
# vb: pd.pivot_table(sc, index=["Leeftijd"], columns=["Regio"], values=["id"], aggfunc=len)

# %% [markdown]
# maak nu een draaitabel met:
# als rij-variabele Regio
# als kolom-variabele Woonomgeving
